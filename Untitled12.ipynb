# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
Icecream = pd.read_csv("IceCreamData.csv")
Icecream.head()
Icecream.tail()
Icecream.describe()
Icecream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
Icecream.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
sns.jointplot(x='Temperature',y='Revenue',data=Icecream)
sns.pairplot(Icecream)
sns.lmplot(x='Temperature',y='Revenue',data=Icecream)

# %%
y = Icecream['Revenue']
x = Icecream[['Temperature']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
x_train.shape

from sklearn.linear_model import LinearRegression
print(x_train.shape)
print(x_test.shape)
# Out:
# (375, 1)
# (125, 1)

# %%
regressor = LinearRegression(fit_intercept=True)
regressor.fit(x_train,y_train)
print('Linear Model coefficient(m):',regressor.coef_)
print('Linear Model Corfficient(b):',regressor.intercept_)
# Out:
# Linear Model coefficient(m): [21.42847868]
# Linear Model Corfficient(b): 44.17764425362111

# %%
y_predict = regressor.predict(x_test)
y_predict
# Out:
# array([468.83736449, 557.94538158, 366.22864513, 501.08407448,
#        718.55810351, 621.53881596, 307.01688528, 530.14468577,
#         49.89964159, 630.79084105, 461.92033257, 605.42524713,
#        538.2372251 , 157.90945226, 387.4827742 , 418.21520282,
#        477.97897764, 440.78365021, 620.03771396, 589.70034806,
#        519.27270647, 562.40262814, 743.45014927, 861.5955226 ,
#        638.20592996, 807.65130324, 670.78390173, 412.73526368,
#        243.66275791, 427.13025245, 611.09056468, 534.2589946 ,
#        407.49273945, 796.20572235, 473.82262548, 620.06700026,
#        684.46000596, 537.10741349, 658.08624219, 590.53151031,
#        557.68712512, 711.88968738, 569.79364129, 484.67600422,
#        282.7345916 , 398.94417059, 645.16942396, 416.19171929,
#        320.64301851, 547.69400959, 756.69382273, 310.60090998,
#        446.50500451, 563.61194883, 619.74064346, 601.23223557,
#        451.00320861, 911.47365835, 447.28641434, 590.59707375,
#        898.30387007, 545.83678706, 311.23943065, 442.80628131,
#        455.49624802, 519.66521234, 669.56875121, 355.98798481,
#        942.55475146, 624.2167203 , 180.30118438, 621.54920727,
#        256.32586735, 283.91425271, 493.05956136, 701.31613329,
#        228.18287939, 891.45774091, 237.43809851, 796.74906007,
#        248.97552676, 518.14785748, 661.10572034, 352.31267436,
#        540.31125069, 484.81176906, 538.91115504, 386.86931436,
#        358.87509281, 473.09831012, 569.03559472, 634.087209  ,
#        655.91758372, 310.98006013, 688.85748872, 621.10955274,
#        263.71364365, 579.04202183, 501.84760846, 625.5196678 ,
#        199.77729354, 420.76675606, 257.48437118, 337.91451311,
#        254.44481562, 589.49471245, 583.99154741, 245.67989797,
#        782.86378667, 466.92033207, 449.35779009, 503.27332379,
#        148.4459134 , 464.55887022, 316.07138845, 402.11577679,
#        544.51192551, 739.85257599, 605.34599862, 604.93648432,
#        649.99855127, 492.77443809, 303.95539146, 493.55754571,
#        313.92269703])

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated vs. Temperature @Ice Cream Stand(Training Dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @Ice Cream Stand(Training Dataset)')

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,regressor.predict(x_test),color='blue')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Hours')
plt.title('Revenue Generated vs. Hours @Ice Cream Stand(Test Dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Hours @Ice Cream Stand(Test Dataset)')

# %%
from sklearn.metrics import accuracy_score

# %%
acc_lr = 97.43

# %%
ls = [1,2,3,4,5]
print(ls[-1])
# Out:
# 5

# %%
dataset = pd.read_csv('Salary_Data.csv')
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,1].values
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 1/3,random_state = 0)

# %%
x_train
# Out:
# array([[ 2.9],
#        [ 5.1],
#        [ 3.2],
#        [ 4.5],
#        [ 8.2],
#        [ 6.8],
#        [ 1.3],
#        [10.5],
#        [ 3. ],
#        [ 2.2],
#        [ 5.9],
#        [ 6. ],
#        [ 3.7],
#        [ 3.2],
#        [ 9. ],
#        [ 2. ],
#        [ 1.1],
#        [ 7.1],
#        [ 4.9],
#        [ 4. ]])

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
acc_lr = 97.49
